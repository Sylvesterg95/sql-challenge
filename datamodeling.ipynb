# %%
import pandas as pd
import os

# List of file paths with corrected syntax
file_paths = [
    r'C:\Users\sylve\sql-challenge\EmployeeSQL\departments.csv',
    r'C:\Users\sylve\sql-challenge\EmployeeSQL\dept_emp.csv',
    r'C:\Users\sylve\sql-challenge\EmployeeSQL\dept_manager.csv',
    r'C:\Users\sylve\sql-challenge\EmployeeSQL\employees.csv',
    r'C:\Users\sylve\sql-challenge\EmployeeSQL\salaries.csv',
    r'C:\Users\sylve\sql-challenge\EmployeeSQL\titles.csv'
]

# Inspect each file
for file_path in file_paths:
    if os.path.exists(file_path):
        print(f"\n--- Inspecting {file_path} ---")
        df = pd.read_csv(file_path)
        print(f"Shape: {df.shape}")  # Rows and columns
        print("Columns:", df.columns.tolist())  # Column names
        print(df.head(), "\n")  # First 5 rows
    else:
        print(f"File not found: {file_path}")
# Out:
# --- Inspecting C:\Users\sylve\sql-challenge\EmployeeSQL\departments.csv ---
# Shape: (9, 2)
# Columns: ['dept_no', 'dept_name']
#   dept_no        dept_name
# 0    d001        Marketing
# 1    d002          Finance
# 2    d003  Human Resources
# 3    d004       Production
# 4    d005      Development
#
#
# --- Inspecting C:\Users\sylve\sql-challenge\EmployeeSQL\dept_emp.csv ---
# Shape: (331603, 2)
# Columns: ['emp_no', 'dept_no']
#    emp_no dept_no
# 0   10001    d005
# 1   10002    d007
# 2   10003    d004
# 3   10004    d004
# 4   10005    d003
#
#
# --- Inspecting C:\Users\sylve\sql-challenge\EmployeeSQL\dept_manager.csv ---
# Shape: (24, 2)
# Columns: ['dept_no', 'emp_no']
#   dept_no  emp_no
# 0    d001  110022
# 1    d001  110039
# 2    d002  110085
# 3    d002  110114
# 4    d003  110183
#
#
# --- Inspecting C:\Users\sylve\sql-challenge\EmployeeSQL\employees.csv ---
# Shape: (300024, 7)
# ...
